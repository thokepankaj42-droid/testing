# %%
r=100
radius=r*r
pi=3.14
area=pi*radius
print(f'area is : {area}')
# Out:
# area is : 31400.0

# %%
r=200
rectangle=r*r
pi=3.14
area=pi*rectangle
print(f' area is :{rectangle}')
# Out:
#  area is :40000

# %%
r=10
square=r*r
pi=3.14
area=pi*square
print(f' area is : {square}')
# Out:
#  area is : 100

# %%
m=eval(input('enter the length in meter'))
meter=m*100
print
# Out:
# area is:400

# %%
pound = float(input('enter weight in pound:'))
kgs = pound*0.453592
print(f' weight in kilograms:{kgs}')
# Out:
# enter weight in pound: 50
#  weight in kilograms:22.6796

# %%
dollar= eval(input('Enter your amount in Dollars : '))
form=dollar*95.68
print(f'The converted dollar value in rupees is : Rs.{form}')
# Out:
# Enter your amount in Dollars :  2
# The converted dollar value in rupees is : Rs.191.36

# %%
c = 10
triangle = c*c
pi=3.14
area=pi*triangle
print(f' area is {triangle}')
# Out:
#  area is 100
